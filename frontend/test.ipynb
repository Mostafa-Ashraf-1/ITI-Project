# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
backend = os.getenv("BACKEND_URL")
backend
# Out:
# 'http://localhost:8000'

# %%
import os 
import pprint 
env_var = os.environ 
print("User's Environment variable:") 
pprint.pprint(dict(env_var), width = 1)
# Out:
# User's Environment variable:
# {'ACSETUPSVCPORT': '23210',
#  'ACSVCPORT': '17532',
#  'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\X-COMPUTER\\AppData\\Roaming',
#  'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1',
#  'APPLICATION_INSIGHTS_NO_STATSBEAT': 'true',
#  'AWS_SDK_LOAD_CONFIG': 'true',
#  'CARBON_MEM_DISABLE': '1',
#  'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_15500_PIUQJBBAJSGITHAQ',
#  'CLICOLOR': '1',
#  'CLICOLOR_FORCE': '1',
#  'CLION': 'D:\\CLion '
#           '2023.2.2\\bin;',
#  'COMMONPROGRAMFILES': 'C:\\Program '
#                        'Files\\Common '
#                        'Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program '
#                             'Files '
#                             '(x86)\\Common '
#                             'Files',
#  'COMMONPROGRAMW6432': 'C:\\Program '
#                        'Files\\Common '
#                        'Files',
#  'COMMONPROPERTYBAGPATH': 'C:\\Users\\X-COMPUTER\\AppData\\Local\\Temp\\csdevkit\\41bd4b77.json',
#  'COMMONPROPERTYBAGWITHCONFIGPATH': 'C:\\Users\\X-COMPUTER\\AppData\\Local\\Temp\\csdevkit\\610e02afef431790162497490.json',
#  'COMPUTERNAME': 'MOSTAFA',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'COPILOT_OTEL_FILE_EXPORTER_PATH': '\\\\.\\nul',
#  'DEBUG': 'release',
#  'DOTNET_CLI_UI_LANGUAGE': 'en-US',
#  'DOTNET_NOLOGO': 'true',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'EFC_14396_1592913036': '1',
#  'EFC_14396_4126798990': '1',
#  'ELECTRON_RUN_AS_NODE': '1',
#  'ENABLELOG': 'INFO',
#  'FORCE_COLOR': '1',
#  'GIT_PAGER': 'cat',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\X-COMPUTER',
#  'IDF_TOOLS_PATH': 'C:\\Espressif',
#  'INTELLIJ IDEA COMMUNITY EDITION': 'D:\\IntelliJ '
#                                     'IDEA '
#                                     'Community '
#                                     'Edition '
#                                     '2024.3.2.2\\bin;',
#  'JAVA_HOME': 'C:\\Program '
#               'Files\\Zulu\\zulu-23\\',
#  'JD2_HOME': 'C:\\Users\\X-COMPUTER\\AppData\\Local\\JDownloader '
#              '2',
#  'JPY_INTERRUPT_EVENT': '4396',
#  'LOCALAPPDATA': 'C:\\Users\\X-COMPUTER\\AppData\\Local',
#  'LOGONSERVER': '\\\\MOSTAFA',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline',
#  'MXC_BIN_DIR': 'c:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Microsoft '
#                 'VS '
#                 'Code\\7debcd0e2a\\resources\\app\\node_modules.asar.unpacked\\@microsoft\\mxc-sdk\\bin',
#  'NODE_TLS_REJECT_UNAUTHORIZED': 'undefined',
#  'NODE_UNC_HOST_ALLOWLIST': 'wsl.localhost',
#  'NUMBER_OF_PROCESSORS': '16',
#  'ONEDRIVE': 'C:\\Users\\X-COMPUTER\\OneDrive',
#  'OS': 'Windows_NT',
#  'PAGER': 'cat',
#  'PATH': 'c:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Python\\Python312;c:\\Users\\X-COMPUTER\\AppData\\Roaming\\Python\\Python312\\Scripts;C:\\bin\\;C:\\Program '
#          'Files\\Zulu\\zulu-23\\bin\\;C:\\Program '
#          'Files '
#          '(x86)\\Common '
#          'Files\\Oracle\\Java\\java8path;C:\\Program '
#          'Files '
#          '(x86)\\Common '
#          'Files\\Oracle\\Java\\javapath;D:\\Security\\vmware\\bin\\;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program '
#          'Files '
#          '(x86)\\NVIDIA '
#          'Corporation\\PhysX\\Common;C:\\Program '
#          'Files\\dotnet\\;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program '
#          'Files\\NVIDIA '
#          'Corporation\\NVIDIA '
#          'app\\NvDLISR;C:\\Program '
#          'Files\\MySQL\\MySQL '
#          'Server '
#          '8.0\\bin;C:\\Program '
#          'Files '
#          '(x86)\\Microsoft '
#          'SQL '
#          'Server\\160\\Tools\\Binn\\;C:\\Program '
#          'Files\\Microsoft '
#          'SQL '
#          'Server\\160\\Tools\\Binn\\;C:\\Program '
#          'Files\\Microsoft '
#          'SQL '
#          'Server\\Client '
#          'SDK\\ODBC\\170\\Tools\\Binn\\;C:\\Program '
#          'Files\\Microsoft '
#          'SQL '
#          'Server\\160\\DTS\\Binn\\;C:\\Program '
#          'Files '
#          '(x86)\\Microsoft '
#          'SQL '
#          'Server\\160\\DTS\\Binn\\;C:\\Program '
#          'Files\\Git\\cmd;C:\\Program '
#          'Files\\nodejs\\;C:\\Program '
#          'Files\\MiKTeX\\miktex\\bin\\x64\\;C:\\Program '
#          'Files\\MATLAB\\R2025b\\bin;C:\\Program '
#          'Files\\MATLAB\\R2024b\\runtime\\win64;C:\\Program '
#          'Files\\MATLAB\\R2024b\\bin;;C:\\Program '
#          'Files\\Docker\\Docker\\resources\\bin;C:\\Program '
#          'Files\\GitHub '
#          'CLI\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Muse '
#          'Hub\\lib;C:\\Program '
#          'Files\\MySQL\\MySQL '
#          'Shell '
#          '8.0\\bin\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Python\\Python312\\Scripts\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Python\\Python312\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Python\\Launcher\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Microsoft\\WindowsApps;C:\\MinGW\\bin;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Microsoft '
#          'VS '
#          'Code\\bin;C:\\Users\\X-COMPUTER\\PycharmProjects\\pythonProject\\venv\\Scripts;D:\\PyCharm '
#          '2023.2.5\\bin;D:\\CLion '
#          '2023.2.2\\bin;C:\\Program '
#          'Files\\R\\R-4.3.2\\bin\\x64;C:\\Users\\X-COMPUTER\\Downloads\\jsonlite_1.8.8\\jsonlite\\R;C:\\Program '
#          'Files\\R\\R-4.3.2\\bin\\R.exe;C:\\Users\\X-COMPUTER\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\Scripts;C:\\Users\\X-COMPUTER\\AppData\\Local\\Coursier\\data\\bin;C:\\Program '
#          'Files\\Java\\jre1.8.0_421\\bin;D:\\IntelliJ '
#          'IDEA '
#          'Community '
#          'Edition '
#          '2024.3.2.2\\bin;;C:\\Users\\X-COMPUTER\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\X-COMPUTER\\AppData\\Roaming\\npm;C:\\Users\\X-COMPUTER\\.dotnet\\tools;C:\\Users\\X-COMPUTER\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\X-COMPUTER\\AppData\\Local\\Kingsoft\\WPS '
#          'Office\\12.1.0.27458\\clitool;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Amazon\\AWSCLIV2\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Microsoft\\WinGet\\Packages\\Hashicorp.Terraform_Microsoft.Winget.Source_8wekyb3d8bbwe;C:\\Users\\X-COMPUTER\\AppData\\Local\\Muse '
#          'Hub\\lib;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Ollama;C:\\bin\\;C:\\Program '
#          'Files\\Zulu\\zulu-23\\bin\\;C:\\Program '
#          'Files '
#          '(x86)\\Common '
#          'Files\\Oracle\\Java\\java8path;C:\\Program '
#          'Files '
#          '(x86)\\Common '
#          'Files\\Oracle\\Java\\javapath;D:\\Security\\vmware\\bin\\;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program '
#          'Files '
#          '(x86)\\NVIDIA '
#          'Corporation\\PhysX\\Common;C:\\Program '
#          'Files\\dotnet\\;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program '
#          'Files\\NVIDIA '
#          'Corporation\\NVIDIA '
#          'app\\NvDLISR;C:\\Program '
#          'Files\\MySQL\\MySQL '
#          'Server '
#          '8.0\\bin;C:\\Program '
#          'Files '
#          '(x86)\\Microsoft '
#          'SQL '
#          'Server\\160\\Tools\\Binn\\;C:\\Program '
#          'Files\\Microsoft '
#          'SQL '
#          'Server\\160\\Tools\\Binn\\;C:\\Program '
#          'Files\\Microsoft '
#          'SQL '
#          'Server\\Client '
#          'SDK\\ODBC\\170\\Tools\\Binn\\;C:\\Program '
#          'Files\\Microsoft '
#          'SQL '
#          'Server\\160\\DTS\\Binn\\;C:\\Program '
#          'Files '
#          '(x86)\\Microsoft '
#          'SQL '
#          'Server\\160\\DTS\\Binn\\;C:\\Program '
#          'Files\\Git\\cmd;C:\\Program '
#          'Files\\nodejs\\;C:\\Program '
#          'Files\\MiKTeX\\miktex\\bin\\x64\\;C:\\Program '
#          'Files\\MATLAB\\R2025b\\bin;C:\\Program '
#          'Files\\MATLAB\\R2024b\\runtime\\win64;C:\\Program '
#          'Files\\MATLAB\\R2024b\\bin;;C:\\Program '
#          'Files\\Docker\\Docker\\resources\\bin;C:\\Program '
#          'Files\\GitHub '
#          'CLI\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Muse '
#          'Hub\\lib;C:\\Program '
#          'Files\\MySQL\\MySQL '
#          'Shell '
#          '8.0\\bin\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Python\\Python312\\Scripts\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Python\\Python312\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Python\\Launcher\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Microsoft\\WindowsApps;C:\\MinGW\\bin;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Microsoft '
#          'VS '
#          'Code\\bin;C:\\Users\\X-COMPUTER\\PycharmProjects\\pythonProject\\venv\\Scripts;D:\\PyCharm '
#          '2023.2.5\\bin;D:\\CLion '
#          '2023.2.2\\bin;C:\\Program '
#          'Files\\R\\R-4.3.2\\bin\\x64;C:\\Users\\X-COMPUTER\\Downloads\\jsonlite_1.8.8\\jsonlite\\R;C:\\Program '
#          'Files\\R\\R-4.3.2\\bin\\R.exe;C:\\Users\\X-COMPUTER\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\Scripts;C:\\Users\\X-COMPUTER\\AppData\\Local\\Coursier\\data\\bin;C:\\Program '
#          'Files\\Java\\jre1.8.0_421\\bin;D:\\IntelliJ '
#          'IDEA '
#          'Community '
#          'Edition '
#          '2024.3.2.2\\bin;;C:\\Users\\X-COMPUTER\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\X-COMPUTER\\AppData\\Roaming\\npm;C:\\Users\\X-COMPUTER\\.dotnet\\tools;C:\\Users\\X-COMPUTER\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\X-COMPUTER\\AppData\\Local\\Kingsoft\\WPS '
#          'Office\\12.1.0.27458\\clitool;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Amazon\\AWSCLIV2\\;C:\\Users\\X-COMPUTER\\AppData\\Local\\Microsoft\\WinGet\\Packages\\Hashicorp.Terraform_Microsoft.Winget.Source_8wekyb3d8bbwe;C:\\Users\\X-COMPUTER\\AppData\\Local\\Muse '
#          'Hub\\lib;C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Ollama',
#  'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#  'POSTHOG_API_KEY': 'phc_jZKK9l8y7YXMN4J5tT0Idkmr9RMZrIUlfVSiaKyTesv',
#  'PROCESSOR_ARCHITECTURE': 'AMD64',
#  'PROCESSOR_IDENTIFIER': 'AMD64 '
#                          'Family '
#                          '23 '
#                          'Model '
#                          '96 '
#                          'Stepping '
#                          '1, '
#                          'AuthenticAMD',
#  'PROCESSOR_LEVEL': '23',
#  'PROCESSOR_REVISION': '6001',
#  'PROGRAMDATA': 'C:\\ProgramData',
#  'PROGRAMFILES': 'C:\\Program '
#                  'Files',
#  'PROGRAMFILES(X86)': 'C:\\Program '
#                       'Files '
#                       '(x86)',
#  'PROGRAMW6432': 'C:\\Program '
#                  'Files',
#  'PSMODULEPATH': 'C:\\Program '
#                  'Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules;C:\\Program '
#                  'Files '
#                  '(x86)\\Microsoft '
#                  'SQL '
#                  'Server\\160\\Tools\\PowerShell\\Modules\\',
#  'PT8HOME': 'D:\\Cisco '
#             'Packet '
#             'Tracer '
#             '8.2.2',
#  'PUBLIC': 'C:\\Users\\Public',
#  'PYCHARM': 'D:\\PyCharm '
#             '2023.2.5\\bin;',
#  'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'PYTHONIOENCODING': 'utf-8',
#  'PYTHONUNBUFFERED': '1',
#  'PYTHON_FROZEN_MODULES': 'on',
#  'RLSSVCPORT': '22112',
#  'SESSIONNAME': 'Console',
#  'SYSTEMDRIVE': 'C:',
#  'SYSTEMROOT': 'C:\\WINDOWS',
#  'TEMP': 'C:\\Users\\X-COMP~1\\AppData\\Local\\Temp',
#  'TERM': 'xterm-color',
#  'TMP': 'C:\\Users\\X-COMP~1\\AppData\\Local\\Temp',
#  'USERDOMAIN': 'MOSTAFA',
#  'USERDOMAIN_ROAMINGPROFILE': 'MOSTAFA',
#  'USERNAME': 'X-COMPUTER',
#  'USERPROFILE': 'C:\\Users\\X-COMPUTER',
#  'VBOX_MSI_INSTALL_PATH': 'C:\\Program '
#                           'Files\\Oracle\\VirtualBox\\',
#  'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\X-COMPUTER\\AppData\\Roaming\\Code\\CachedData\\7debcd0e2acdea1c52de81bf9ee1620444407dda',
#  'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#  'VSCODE_CWD': 'C:\\Users\\X-COMPUTER\\AppData\\Local\\Programs\\Microsoft '
#                'VS '
#                'Code',
#  'VSCODE_DOTNET_INSTALL_TOOL_ORIGINAL_HOME': 'undefined',
#  'VSCODE_ESM_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#  'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#  'VSCODE_IPC_HOOK': '\\\\.\\pipe\\69540a29-1.138.0-main-sock',
#  'VSCODE_L10N_BUNDLE_LOCATION': '',
#  'VSCODE_NLS_CONFIG': '{"userLocale":"en-us","osLocale":"en-us","resolvedLanguage":"en","defaultMessagesFile":"C:\\\\Users\\\\X-COMPUTER\\\\AppData\\\\Local\\\\Programs\\\\Microsoft '
#                       'VS '
#                       'Code\\\\7debcd0e2a\\\\resources\\\\app\\\\out\\\\nls.messages.json","locale":"en-us","availableLanguages":{}}',
#  'VSCODE_PID': '15500',
#  'WEBOTS_HOME': 'D:\\Webots',
#  'WINDIR': 'C:\\WINDOWS',
#  'WPSCLI_HOME': 'C:\\Users\\X-COMPUTER\\AppData\\Local\\Kingsoft\\WPS '
#                 'Office\\12.1.0.27458\\clitool',
#  '__TELEMETRY_CLIENT_ID': '0efd1688-9f0d-4424-b414-d67f8f6ac740'}
